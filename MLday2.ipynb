# %% [markdown]
# <a href="https://colab.research.google.com/github/Aman1477r/ML-journey/blob/main/MLday2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_classification

# %%
X,y= make_classification(n_samples=1000,n_redundant=0,n_features=2,n_clusters_per_class=1,
                    weights=[0.90],random_state=22)

# %%
import pandas as pd

# %%
df1 = pd.DataFrame(X,columns = ['f1','f2'])
df2 = pd.DataFrame(y,columns=['target'])
final_df = pd.concat([df1,df2], axis=1)
final_df.head()
# Out:
#          f1        f2  target
# 0  0.303280  0.481391       0
# 1  0.739692  0.919562       0
# 2  1.196646  1.112372       0
# 3 -0.857798 -0.734274       1
# 4  2.583395  1.757324       0

# %%
final_df['target'].value_counts()
# Out:
# target
# 0    899
# 1    101
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(final_df['f1'],final_df['f2'],c=final_df['target'])
plt.show()

# %%
from imblearn.over_sampling import SMOTE

# %%
oversample = SMOTE()

# %%
X,y = oversample.fit_resample(final_df[['f1','f2']],final_df['target'])

# %%
X.shape
# Out:
# (1798, 2)

# %%
y.shape
# Out:
# (1798,)

# %%
len(y[y==0])
# Out:
# 899

# %%
plt.scatter(X['f1'],X['f2'],c=y)
plt.show()
#

# %%
import numpy as np

# %%
lst_marks = [32,43,31,55,67,87,99,77,66,54,37,90,100]
minimum,Q1,median,Q3,maximum = np.quantile(lst_marks,[0,0.25,0.50,0.75,1.0])

# %%
minimum,Q1,median,Q3,maximum
# Out:
# (np.float64(31.0),
#  np.float64(43.0),
#  np.float64(66.0),
#  np.float64(87.0),
#  np.float64(100.0))

# %%
IQR = Q3-Q1
print(IQR)
# Out:
# 44.0

# %%
lower_fen = Q1 - 1.5 *(IQR)
higer_fen = Q3 + 1.5 *(IQR)

# %%
lower_fen
# Out:
# np.float64(-23.0)

# %%
higer_fen
# Out:
# np.float64(153.0)

# %%
import seaborn as sns

# %%
sns.boxenplot(lst_marks)
plt.show()

# %%
lsr_marks = [-32,-44,32,43,31,55,67,87,99,77,66,54,37,90,100,199,200]

# %%
sns.boxenplot(lsr_marks)
plt.show()
