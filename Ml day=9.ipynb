# %% [markdown]
# <a href="https://colab.research.google.com/github/Aman1477r/ML-journey/blob/main/Ml%20day%3D9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
s = pd.Series([10,20,30,40,50])

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 5 entries, 0 to 4
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 5 non-null      int64
# dtypes: int64(1)
# memory usage: 172.0 bytes

# %%
s.describe()
# Out:
# count     5.000000
# mean     30.000000
# std      15.811388
# min      10.000000
# 25%      20.000000
# 50%      30.000000
# 75%      40.000000
# max      50.000000
# dtype: float64

# %%
s.name = 'name'

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# Name: name, dtype: int64

# %%
s.index[2]
# Out:
# 2

# %%
s.iloc[2]
# Out:
# np.int64(30)

# %%
s.iloc[2:3]
# Out:
# 2    30
# Name: name, dtype: int64

# %%
s.iloc[1:4]
# Out:
# 1    20
# 2    30
# 3    40
# Name: name, dtype: int64

# %%
index = ['apple','banana','mango','pineapple','kewi']

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# Name: name, dtype: int64

# %%
index
# Out:
# ['apple', 'banana', 'mango', 'pineapple', 'kewi']

# %%
s.index = index

# %%
s
# Out:
# apple        10
# banana       20
# mango        30
# pineapple    40
# kewi         50
# Name: name, dtype: int64

# %%
s.name = 'calories'

# %%
s
# Out:
# apple        10
# banana       20
# mango        30
# pineapple    40
# kewi         50
# Name: calories, dtype: int64

# %%
s['apple']
# Out:
# np.int64(10)

# %%
s.loc['apple']
# Out:
# np.int64(10)

# %%
s.iloc[2]
# Out:
# np.int64(30)

# %%
fruit_protein = {
    'apple':10,
    'banana':20,
    'mango':30,
    'pineapple':40,
    'kewi':50
}

# %%
s2 = pd.Series(fruit_protein,name= 'protein')

# %%
s2
# Out:
# apple        10
# banana       20
# mango        30
# pineapple    40
# kewi         50
# Name: protein, dtype: int64

# %%
### COnditional selection

s2[s2>1]
# Out:
# apple        10
# banana       20
# mango        30
# pineapple    40
# kewi         50
# Name: protein, dtype: int64

# %%
### Logical oprator

s2[(s2>10) & (s2<80)]
# Out:
# banana       20
# mango        30
# pineapple    40
# kewi         50
# Name: protein, dtype: int64

# %%
### modify seris

s2['apple'] = 90

# %%
s2
# Out:
# apple        90
# banana       20
# mango        30
# pineapple    40
# kewi         50
# Name: protein, dtype: int64

# %%
import numpy as np

# %%
ser = pd.Series(['a',np.nan,1,np.nan,2])

# %%
s.isnull().sum()
# Out:
# np.int64(0)

# %%
s.notnull().sum()
# Out:
# np.int64(5)

# %%
data = {
    "Name":["Jai", "Princi", "Gaurav", "Anuj"],
    "Age":[27, 24, 22, 32],
    "Department": ["HR","IT","Financ","HR"],
    "Salary" : [80000,4000,5000,np.nan]
}

# %%
data
# Out:
# {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'],
#  'Age': [27, 24, 22, 32],
#  'Department': ['HR', 'IT', 'Financ', 'HR'],
#  'Salary': [80000, 4000, 5000, nan]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      Name  Age Department   Salary
# 0     Jai   27         HR  80000.0
# 1  Princi   24         IT   4000.0
# 2  Gaurav   22     Financ   5000.0
# 3    Anuj   32         HR      NaN

# %%
df.head()
# Out:
#      Name  Age Department   Salary
# 0     Jai   27         HR  80000.0
# 1  Princi   24         IT   4000.0
# 2  Gaurav   22     Financ   5000.0
# 3    Anuj   32         HR      NaN

# %%
df[['Age','Salary']]
# Out:
#    Age   Salary
# 0   27  80000.0
# 1   24   4000.0
# 2   22   5000.0
# 3   32      NaN

# %%
df.drop("Age",axis=1,inplace=False)
# Out:
#      Name Department   Salary
# 0     Jai         HR  80000.0
# 1  Princi         IT   4000.0
# 2  Gaurav     Financ   5000.0
# 3    Anuj         HR      NaN

# %%
df
# Out:
#      Name  Age Department   Salary
# 0     Jai   27         HR  80000.0
# 1  Princi   24         IT   4000.0
# 2  Gaurav   22     Financ   5000.0
# 3    Anuj   32         HR      NaN

# %%
df.shape
# Out:
# (4, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        4 non-null      object
#  1   Age         4 non-null      int64
#  2   Department  4 non-null      object
#  3   Salary      3 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 260.0+ bytes

# %%
df.describe()
# Out:
#              Age        Salary
# count   4.000000      3.000000
# mean   26.250000  29666.666667
# std     4.349329  43592.812863
# min    22.000000   4000.000000
# 25%    23.500000   4500.000000
# 50%    25.500000   5000.000000
# 75%    28.250000  42500.000000
# max    32.000000  80000.000000

# %%
df['Salary'] =df['Salary'] + 5000

# %%
df['Salary']
# Out:
# 0    85000.0
# 1     9000.0
# 2    10000.0
# 3        NaN
# Name: Salary, dtype: float64

# %%
df
# Out:
#      Name  Age Department   Salary
# 0     Jai   27         HR  85000.0
# 1  Princi   24         IT   9000.0
# 2  Gaurav   22     Financ  10000.0
# 3    Anuj   32         HR      NaN

# %%
### Rename

df.rename(columns={"Department": "Dept"}, inplace=True)

# %%
df
# Out:
#      Name  Age    Dept   Salary
# 0     Jai   27      HR  85000.0
# 1  Princi   24      IT   9000.0
# 2  Gaurav   22  Financ  10000.0
# 3    Anuj   32      HR      NaN

# %%
df["Salary"].unique()
# Out:
# array([85000.,  9000., 10000.,    nan])

# %%
df["Dept"].value_counts()
# Out:
# Dept
# HR        2
# IT        1
# Financ    1
# Name: count, dtype: int64

# %%
df["promoted_salry"] = df["Salary"] * 10

# %%
df
# Out:
#      Name  Age    Dept   Salary  promoted_salry
# 0     Jai   27      HR  85000.0        850000.0
# 1  Princi   24      IT   9000.0         90000.0
# 2  Gaurav   22  Financ  10000.0        100000.0
# 3    Anuj   32      HR      NaN             NaN

# %%
df.isnull().sum()
# Out:
# Name              0
# Age               0
# Dept              0
# Salary            1
# promoted_salry    1
# dtype: int64

# %%
df.dropna(how = "any")
# Out:
#      Name  Age    Dept   Salary  promoted_salry
# 0     Jai   27      HR  85000.0        850000.0
# 1  Princi   24      IT   9000.0         90000.0
# 2  Gaurav   22  Financ  10000.0        100000.0

# %%
df
# Out:
#      Name  Age    Dept   Salary  promoted_salry
# 0     Jai   27      HR  85000.0        850000.0
# 1  Princi   24      IT   9000.0         90000.0
# 2  Gaurav   22  Financ  10000.0        100000.0
# 3    Anuj   32      HR      NaN             NaN

# %%
df.dropna(how = "all")
# Out:
#      Name  Age    Dept   Salary  promoted_salry
# 0     Jai   27      HR  85000.0        850000.0
# 1  Princi   24      IT   9000.0         90000.0
# 2  Gaurav   22  Financ  10000.0        100000.0
# 3    Anuj   32      HR      NaN             NaN

# %%
df.fillna(0)
# Out:
#      Name  Age    Dept   Salary  promoted_salry
# 0     Jai   27      HR  85000.0        850000.0
# 1  Princi   24      IT   9000.0         90000.0
# 2  Gaurav   22  Financ  10000.0        100000.0
# 3    Anuj   32      HR      0.0             0.0

# %%
df['Age'].fillna(df['Age'].mean())
# Out:
# 0    27
# 1    24
# 2    22
# 3    32
# Name: Age, dtype: int64

# %%
df['Salary'].fillna(df['Salary'].median())
# Out:
# 0    85000.0
# 1     9000.0
# 2    10000.0
# 3    10000.0
# Name: Salary, dtype: float64

# %%
df['Salary'].fillna(method = 'ffill')
# Out:
# /tmp/ipykernel_1540/694346041.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Salary'].fillna(method = 'ffill')
# 0    85000.0
# 1     9000.0
# 2    10000.0
# 3    10000.0
# Name: Salary, dtype: float64

# %%
df
# Out:
#      Name  Age    Dept   Salary  promoted_salry
# 0     Jai   27      HR  85000.0        850000.0
# 1  Princi   24      IT   9000.0         90000.0
# 2  Gaurav   22  Financ  10000.0        100000.0
# 3    Anuj   32      HR      NaN             NaN

# %%
df["Name"] = df["Name"].replace("Jai","Ashish")

# %%
df
# Out:
#      Name  Age    Dept   Salary  promoted_salry
# 0  Ashish   27      HR  85000.0        850000.0
# 1  Princi   24      IT   9000.0         90000.0
# 2  Gaurav   22  Financ  10000.0        100000.0
# 3    Anuj   32      HR      NaN             NaN

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool

# %%
df_dup = df[df.duplicated(keep="last")]

# %%
df_dup
# Out:
# Empty DataFrame
# Columns: [Name, Age, Dept, Salary, promoted_salry]
# Index: []

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#      Name  Age    Dept   Salary  promoted_salry
# 0  Ashish   27      HR  85000.0        850000.0
# 1  Princi   24      IT   9000.0         90000.0
# 2  Gaurav   22  Financ  10000.0        100000.0
# 3    Anuj   32      HR      NaN             NaN

# %%
### Invalid Value Using lamda

df["promoted_salry"] = df["promoted_salry"].apply(lambda x: x/10 if x > 650000 else x)

# %%
df
# Out:
#      Name  Age    Dept   Salary  promoted_salry
# 0  Ashish   27      HR  85000.0         85000.0
# 1  Princi   24      IT   9000.0         90000.0
# 2  Gaurav   22  Financ  10000.0        100000.0
# 3    Anuj   32      HR      NaN             NaN

# %%
def multiplying_age(x):
  return x*2
df["Age"] = df["Age"].apply(multiplying_age)

# %%
df
# Out:
#      Name  Age    Dept   Salary  promoted_salry
# 0  Ashish   54      HR  85000.0         85000.0
# 1  Princi   48      IT   9000.0         90000.0
# 2  Gaurav   44  Financ  10000.0        100000.0
# 3    Anuj   64      HR      NaN             NaN

# %%
df["Age"] = df["Age"].apply(lambda x: x/2)

# %%
df
# Out:
#      Name   Age    Dept   Salary  promoted_salry
# 0  Ashish  27.0      HR  85000.0         85000.0
# 1  Princi  24.0      IT   9000.0         90000.0
# 2  Gaurav  22.0  Financ  10000.0        100000.0
# 3    Anuj  32.0      HR      NaN             NaN

# %%
### joins and merges

df2 = pd.DataFrame({
    "Location" : ["pune","mumbai","hydrabad"],
    "Manager" : ["lona","seniii","Nina"]
})

# %%
pd.concat([df,df2])
# Out:
#      Name   Age    Dept   Salary  promoted_salry  Location Manager
# 0  Ashish  27.0      HR  85000.0         85000.0       NaN     NaN
# 1  Princi  24.0      IT   9000.0         90000.0       NaN     NaN
# 2  Gaurav  22.0  Financ  10000.0        100000.0       NaN     NaN
# 3    Anuj  32.0      HR      NaN             NaN       NaN     NaN
# 0     NaN   NaN     NaN      NaN             NaN      pune    lona
# 1     NaN   NaN     NaN      NaN             NaN    mumbai  seniii
# 2     NaN   NaN     NaN      NaN             NaN  hydrabad    Nina

# %%
pd.concat([df,df2],axis=1)
# Out:
#      Name   Age    Dept   Salary  promoted_salry  Location Manager
# 0  Ashish  27.0      HR  85000.0         85000.0      pune    lona
# 1  Princi  24.0      IT   9000.0         90000.0    mumbai  seniii
# 2  Gaurav  22.0  Financ  10000.0        100000.0  hydrabad    Nina
# 3    Anuj  32.0      HR      NaN             NaN       NaN     NaN

# %%
dfff = pd.read_csv('raw_dataset.csv')

# %%
dfff
# Out:
#         Unnamed: 0    airline   flight source_city departure_time stops  \
# 0                0   SpiceJet  SG-8709       Delhi        Evening  zero
# 1                1   SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2                2    AirAsia   I5-764       Delhi  Early_Morning  zero
# 3                3    Vistara   UK-995       Delhi        Morning  zero
# 4                4    Vistara   UK-963       Delhi        Morning  zero
# ...            ...        ...      ...         ...            ...   ...
# 218243      218243  Air_India   AI-889       Delhi        Morning   one
# 218244      218244  Air_India   AI-839       Delhi          Night   one
# 218245      218245  Air_India   AI-544       Delhi        Evening   one
# 218246      218246  Air_India   AI-542       Delhi        Morning   one
# 218247      218247  Air_India   AI-560       Delhi          Morni   NaN
#
#          arrival_time destination_city     class  duration  days_left    price
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            4 non-null      object
#  1   Age             4 non-null      float64
#  2   Dept            4 non-null      object
#  3   Salary          3 non-null      float64
#  4   promoted_salry  3 non-null      float64
# dtypes: float64(3), object(2)
# memory usage: 292.0+ bytes
